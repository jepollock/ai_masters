# %% [markdown]
# # AIML428 - Assignment1, Step 5 Pre-Trained Word Embedding
# * Using Glove 50D, no need to load more data than necessary here.

# %%
import keras
import matplotlib.pyplot as plt
import numpy
import os
import pandas as pd
import torch
from IPython.display import Markdown, display
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from keras import layers
from keras.models import Sequential
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split

# %%
def tableHeader():
    doc = "|Algorithm| label | accuracy | precision | recall | f1 |\n"
    doc += "| --- | --- | --- | --- |--- | --- |\n"
    return doc

def tableScore(labels, doc, prefix=None, y_true=None, y_prediction=None):
    rows = ""
    accuracy = accuracy_score(y_true, y_prediction)
    precisions = precision_score(y_true, y_prediction, labels=labels, average=None)
    recalls = recall_score(y_true, y_prediction, labels=labels, average=None)
    f1s = f1_score(y_true, y_prediction, labels=labels, average=None)
    for label, precision, recall, f1 in zip(labels, precisions, recalls, f1s):
        rows += f"| {prefix} | {label} | {accuracy:.4g} | {precision:.4g} | {recall:.4g} | {f1:.4g} |\n"
        prefix = " "
    return doc + rows

def tableFooter(doc):
    display(Markdown(doc))

def report(string):
    display(Markdown(string))

enable_debug = True

def debug(string):
    if (enable_debug):
        print(string)

# %% [markdown]
# ## Try to use a GPU for go faster juice

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Metal (GPU) is available")
else:
    device = torch.device("cpu")
    print("GPU not available, using CPU")

# Encourage Keras to use Torch, and to use the GPU.
os.environ["KERAS_BACKEND"] = "torch"
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
# Out:
# Metal (GPU) is available

# %% [markdown]
# ## Magic to download wordnet

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/jepollock/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jepollock/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/jepollock/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Load the Glove Pre-Trained Embedding
#
# * File is space delimited, `<word> <num> <num> <num>
# * Online documentation is wrong it isn't whitespace delimited, it's _space_ delimited.

# %%
# Bugs: \n on end of line
# Convert embedding from string to float.

def loadGloveEmbedding(filename=None):
    word_to_embedding = {}
    with open(filename, "r") as file:
        for line in file:
            # Can't use the default, because words include nbsp.
            fields = line.rstrip().split(" ")
            word = fields[0]
            try:
                embedding = [float(x) for x in fields[1:]]
            except ValueError:
                print(f"value error: {fields}")
                raise ValueError("BOOM.")
            word_to_embedding[word] = embedding
    return word_to_embedding

embedding = loadGloveEmbedding("data/wiki_giga_2024_50_MFT20_vectors_seed_123_alpha_0.75_eta_0.075_combined.txt")

first_embedding, *_ = embedding.items()
embedding_num_dims=len(first_embedding[1])

debug(f"config_dims= {embedding_num_dims}")
debug(f"first embedding: {first_embedding}")
# Out:
# config_dims= 50
# first embedding: ('the', [-0.383396, -0.480674, -0.27414099999999997, 0.132697, 0.06488499999999997, -0.092489, -0.0029909999999999937, 0.168918, 0.42769, 0.032062000000000035, 0.600652, 0.0045550000000000035, 0.221568, -0.106817, 0.339955, -0.24816500000000002, -0.06553399999999998, 0.16503099999999998, -0.098915, -0.26706, -0.351612, -0.595836, -0.748328, -0.262191, -0.400183, 0.306477, 0.13247, 0.149532, -0.462982, 0.436406, -0.328406, -0.11229700000000001, -0.318158, -0.586177, -0.24174600000000002, -0.38285899999999995, -0.433786, 5.955204999999999, 0.137239, -0.064516, 0.456522, -0.019239000000000006, 0.260624, -0.293577, 0.19897499999999999, 0.277653, 0.164552, 0.40649, -0.227907, -0.400316])

# %% [markdown]
# ## Load the data.

# %%
df_csv = pd.read_csv('bbc_converted.csv')

feature_columns = ['text']
target_column = 'category'

X_csv = df_csv[feature_columns]
Y_csv = df_csv[target_column]
# unique converts to an NDArray, so the sort needs to happen first.
labels = Y_csv.sort_values().unique()
print(labels)
# Out:
# ['business' 'entertainment' 'politics' 'sport' 'tech']

# %%
# https://xkcd.com/221/ - 4 is overused
random_seed = 221

# %%
# Data already loaded
# X_csv is the CSV text data
# Y_csv is the CSV labels - the sorted label set.
debug(X_csv)
debug(Y_csv)
debug(labels)
# Out:
#                                                    text
# 0     musicians to tackle us red tape musicians grou...
# 1     u2 s desire to be number one u2 who have won t...
# 2     rocker doherty in on stage fight rock singer p...
# 3     snicket tops us box office chart the film adap...
# 4     ocean s twelve raids box office ocean s twelve...
# ...                                                 ...
# 2220  warning over windows word files writing a micr...
# 2221  fast lifts rise into record books two high spe...
# 2222  nintendo adds media playing to ds nintendo is ...
# 2223  fast moving phone viruses appear security firm...
# 2224  hacker threat to apple s itunes users of apple...
#
# [2225 rows x 1 columns]
# 0       entertainment
# 1       entertainment
# 2       entertainment
# 3       entertainment
# 4       entertainment
#             ...
# 2220             tech
# 2221             tech
# 2222             tech
# 2223             tech
# 2224             tech
# Name: category, Length: 2225, dtype: object
# ['business' 'entertainment' 'politics' 'sport' 'tech']

# %% [markdown]
# ## Data preprocessing - lemmatization
# * Lemmatization is a preprocessing step, it is applied to the dataset, not learned from Training and applied to Test.

# %%
# From Part-of-speech tagging guidelines for the Penn Treebank Project.
# https://catalog.ldc.upenn.edu/docs/LDC99T42/tagguid1.pdf
tag_dict = {"J": "a", "R":"r", "V": "v"}

def treebank_to_wordnet(treebank_tag:str):
  # n - nouns
  # a - adjective
  # r - adverb
  # s - satellite adjectives
  # default is h
  if (treebank_tag.startswith("WRB")):
      return "r"
  return tag_dict.get(treebank_tag[0], "n")

lemmatizer = WordNetLemmatizer()

def lemmatizeText(text:str):
    accum = []
    tagged_values = pos_tag(word_tokenize(text))
    for t, pos in tagged_values:
        wordnet_tag = treebank_to_wordnet(pos)
        #debug(f"from ({t},{pos}, {wordnet_tag})")
        lemmatized = lemmatizer.lemmatize(word=t,pos=wordnet_tag)
        accum.append(lemmatized)
    result = ' '.join(accum)
    #debug(result)
    return result

X_lemmatized = pd.DataFrame()
X_lemmatized['text'] = X_csv.text.apply(lemmatizeText)

X_lemmatized
# Out:
#                                                    text
# 0     musician to tackle u red tape musician group b...
# 1     u2 s desire to be number one u2 who have win t...
# 2     rocker doherty in on stage fight rock singer p...
# 3     snicket top u box office chart the film adapta...
# 4     ocean s twelve raid box office ocean s twelve ...
# ...                                                 ...
# 2220  warn over window word file write a microsoft w...
# 2221  fast lifts rise into record book two high spee...
# 2222  nintendo add medium play to ds nintendo be rel...
# 2223  fast move phone virus appear security firm be ...
# 2224  hacker threat to apple s itunes user of apple ...
#
# [2225 rows x 1 columns]

# %% [markdown]
# ## Test/Train Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_lemmatized, Y_csv, test_size= 0.3, random_state=random_seed)

debug(f"X columns: {X_train.columns}")
debug(f"X.head: {X_train.text.head(1)}")
debug(f"Y.head: {Y_train.head(1)}")
# Out:
# X columns: Index(['text'], dtype='object')
# X.head: 1187    edward tip idowu for euro gold world outdoor t...
# Name: text, dtype: object
# Y.head: 1187    sport
# Name: category, dtype: object

# %% [markdown]
# ## Create Validation Set
#
# We do it here to make it easier. Tensors can't use the same functions, and the ones they have are interesting in other ways.

# %%
X_train_wv, X_validation, Y_train_wv, Y_validation = (
   train_test_split(X_train, Y_train, test_size=0.2, random_state=random_seed))

# %% [markdown]
# ## Use oversampling for balance - only the training set
#
# SMOTE and ADASYN only work on numeric data. Could do it by converting to vector space too, but that is too much for for today.

# %%
random_oversampler = RandomOverSampler(random_state=random_seed)
X_train_rs, Y_train_rs = random_oversampler.fit_resample(X_train_wv, Y_train_wv)

debug(sorted(Counter(Y_train_rs.tolist()).items()))
debug(X_train_rs.shape)
debug(Y_train_rs.shape)
# Out:
# [('business', 285), ('entertainment', 285), ('politics', 285), ('sport', 285), ('tech', 285)]
# (1425, 1)
# (1425,)

# %% [markdown]
# ## Encode the label
#
# Train on all the _training_ values, but apply it to the _train/_validation variables, and the _test variables.

# %%
# label encode the target variable
encoder = preprocessing.OneHotEncoder(sparse_output=False)

encoder.fit(Y_train.values.reshape(-1, 1))
Y_train_enc = encoder.transform(Y_train_rs.values.reshape(-1, 1))
Y_validation_enc = encoder.transform(Y_validation.values.reshape(-1, 1))
Y_test_enc = encoder.transform(Y_test.values.reshape(-1, 1))

debug(f"Y_train_enc.shape: {Y_train_enc.shape}")
# Out:
# Y_train_enc.shape: (1425, 5)

# %% [markdown]
# ## Vectorization to have an index.
# * train on the entire dataset
# * then vectorize test, train and validation independently

# %%
from tensorflow.keras.layers import TextVectorization

# This is the bit we are going to change with fasttext.

max_tokens = 50000  # Maximum vocab size.
max_len = 70  # Sequence length to pad the outputs to.

vectorize_layer = TextVectorization(
    max_tokens=max_tokens,
    output_mode='int',
    output_sequence_length=max_len)

# Adapt the layer to the training text.
# Create a dict and go.
vectorize_layer.adapt(X_train)
train_vocabulary = vectorize_layer.get_vocabulary()
train_vocab_len = len(train_vocabulary)
X_train_vec = vectorize_layer(X_train_rs)
X_test_vec = vectorize_layer(X_test)
X_validation_vec = vectorize_layer(X_validation)

X_train_vec
# Out:
# <tf.Tensor: shape=(1425, 70), dtype=int64, numpy=
# array([[ 1677, 15823,    12, ...,    79,  8147,    12],
#        [ 2517,   404,     4, ..., 21125,   404,    13],
#        [  518,  2631,     5, ...,     2,   453,   391],
#        ...,
#        [  518,  2631,     5, ...,     2,   453,   391],
#        [  461,   506,     4, ...,   286,    24,   126],
#        [  379,  1493,  2399, ...,    21,    62,     2]])>

# %% [markdown]
# ## Convert loaded Pre-Trained embedding weights into a matrix
#
# * Uses the trained vectorization
# * Inserts them in-order

# %%
# Vocabulary is already in order, there is no need to map it to a dict.
no_mapping = [0] * embedding_num_dims

def translateWord(value):
    vector = embedding.get(value, no_mapping)
    return numpy.array(vector)

embedding_matrix = numpy.array(list(map(translateWord, train_vocabulary)))

debug(len(train_vocabulary))
debug(train_vocab_len)
debug(len(embedding_matrix))
debug(embedding_matrix.shape)

# The code in here is broken: https://realpython.com/python-keras-text-classification/#using-pretrained-word-embeddings
# The code in here is _also_ broken https://keras.io/examples/nlp/pretrained_word_embeddings/
# BUG: word, coefs = line.split(maxsplit=1) -- breaks on nbsp's in words e.g. "..."
# BUG: word_index = dict(zip(voc, range(len(voc)))) -- dict isn't required if the words are in order already.
# Out:
# 21268
# 21268
# 21268
# (21268, 50)

# %% [markdown]
# ## Train the CNN using
# * Data is Lemmatized
# * Data has a validation set
# * Training data was oversampled.
# * Uses Early Stopping

# %%
vocab_size = train_vocab_len
print("vocab_size:", vocab_size)
maxDocumentLength = 70
earlyStoppingMinDelta = 0.0001
earlyStoppingPatience = 8
epochs=500 # demonstrate early stopping works.

model = Sequential()

embedding_layer_name = "Embedding"
model.add(layers.Embedding(
    weights=[embedding_matrix],
    name=embedding_layer_name,
    input_dim=vocab_size,
    output_dim=50, trainable=False))
model.build((50, maxDocumentLength)) # build the first layer with the specific input_length
model.add(layers.Conv1D(filters=128, kernel_size=5, activation='relu'))

model.add(layers.GlobalAveragePooling1D())
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(Y_train_enc.shape[1], activation='sigmoid'))

model.summary()

early_stopping_callback = keras.callbacks.EarlyStopping(monitor="val_loss",
                                                        min_delta=earlyStoppingMinDelta,
                                                        restore_best_weights=True,
                                                        patience=earlyStoppingPatience)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

print(X_train_vec.shape)
print(Y_train_enc.shape)
print(X_validation_vec.shape)
print(Y_validation_enc.shape)

history = model.fit(X_train_vec,
                    Y_train_enc,
                    callbacks=[early_stopping_callback],
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(X_validation_vec, Y_validation_enc),
                    verbose=1)
# Out:
# vocab_size: 21268
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Embedding (Embedding)           │ (50, 70, 50)           │     1,063,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (50, 66, 128)          │        32,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (50, 128)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (50, 16)               │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (50, 5)                │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,097,677 (4.19 MB)
#  Trainable params: 34,277 (133.89 KB)
#  Non-trainable params: 1,063,400 (4.06 MB)
# (1425, 70)
# (1425, 5)
# (312, 70)
# (312, 5)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 0.2014 - loss: 0.7128 - val_acc: 0.1795 - val_loss: 0.6643
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.2281 - loss: 0.6472 - val_acc: 0.2788 - val_loss: 0.6201
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.3565 - loss: 0.6039 - val_acc: 0.3878 - val_loss: 0.5777
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.4793 - loss: 0.5616 - val_acc: 0.4327 - val_loss: 0.5336
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.5298 - loss: 0.5159 - val_acc: 0.4712 - val_loss: 0.4816
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.5586 - loss: 0.4615 - val_acc: 0.5353 - val_loss: 0.4291
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.6021 - loss: 0.4127 - val_acc: 0.5769 - val_loss: 0.3905
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.6604 - loss: 0.3789 - val_acc: 0.6474 - val_loss: 0.3654
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.6982 - loss: 0.3561 - val_acc: 0.6827 - val_loss: 0.3470
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.7004 - loss: 0.3371 - val_acc: 0.6667 - val_loss: 0.3287
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.7032 - loss: 0.3182 - val_acc: 0.6923 - val_loss: 0.3090
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.7291 - loss: 0.2975 - val_acc: 0.7372 - val_loss: 0.2861
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.7804 - loss: 0.2751 - val_acc: 0.7885 - val_loss: 0.2660
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.8260 - loss: 0.2574 - val_acc: 0.8205 - val_loss: 0.2500
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.8484 - loss: 0.2418 - val_acc: 0.8494 - val_loss: 0.2350
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.8611 - loss: 0.2273 - val_acc: 0.8686 - val_loss: 0.2211
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.8737 - loss: 0.2135 - val_acc: 0.8750 - val_loss: 0.2079
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0
500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9712 - loss: 0.0499 - val_acc: 0.9615 - val_loss: 0.0600
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9712 - loss: 0.0496 - val_acc: 0.9615 - val_loss: 0.0600
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9712 - loss: 0.0492 - val_acc: 0.9615 - val_loss: 0.0595
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9712 - loss: 0.0489 - val_acc: 0.9615 - val_loss: 0.0594
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9705 - loss: 0.0485 - val_acc: 0.9615 - val_loss: 0.0592
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9705 - loss: 0.0483 - val_acc: 0.9615 - val_loss: 0.0592
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9719 - loss: 0.0481 - val_acc: 0.9615 - val_loss: 0.0587
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9712 - loss: 0.0476 - val_acc: 0.9615 - val_loss: 0.0587
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9712 - loss: 0.0472 - val_acc: 0.9615 - val_loss: 0.0588
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9719 - loss: 0.0470 - val_acc: 0.9615 - val_loss: 0.0590
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9740 - loss: 0.0466 - val_acc: 0.9615 - val_loss: 0.0584
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9740 - loss: 0.0463 - val_acc: 0.9615 - val_loss: 0.0578
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9733 - loss: 0.0460 - val_acc: 0.9615 - val_loss: 0.0577
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9712 - loss: 0.0460 - val_acc: 0.9615 - val_loss: 0.0582
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9726 - loss: 0.0454 - val_acc: 0.9615 - val_loss: 0.0581
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9740 - loss: 0.0449 - val_acc: 0.9615 - val_loss: 0.0577
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9740 - loss: 0.0449 - val_acc: 0.9615 - val_loss: 0.0572
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9740 - loss: 0.0445 - val_acc: 0.9615 - val_loss: 0.0571
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9733 - loss: 0.0440 - val_acc: 0.9615 - val_loss: 0.0576
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9740 - loss: 0.0440 - val_acc: 0.9615 - val_loss: 0.0576
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9747 - loss: 0.0435 - val_acc: 0.9615 - val_loss: 0.0569
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9733 - loss: 0.0433 - val_acc: 0.9615 - val_loss: 0.0565
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9740 - loss: 0.0430 - val_acc: 0.9615 - val_loss: 0.0565
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9740 - loss: 0.0427 - val_acc: 0.9615 - val_loss: 0.0567
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9733 - loss: 0.0427 - val_acc: 0.9615 - val_loss: 0.0566
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9740 - loss: 0.0424 - val_acc: 0.9615 - val_loss: 0.0562
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9761 - loss: 0.0418 - val_acc: 0.9615 - val_loss: 0.0561
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9740 - loss: 0.0415 - val_acc: 0.9615 - val_loss: 0.0562
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9747 - loss: 0.0411 - val_acc: 0.9615 - val_loss: 0.0558
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9754 - loss: 0.0409 - val_acc: 0.9615 - val_loss: 0.0557
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9768 - loss: 0.0407 - val_acc: 0.9615 - val_loss: 0.0559
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9768 - loss: 0.0405 - val_acc: 0.9615 - val_loss: 0.0560
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9747 - loss: 0.0401 - val_acc: 0.9615 - val_loss: 0.0555
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9754 - loss: 0.0397 - val_acc: 0.9615 - val_loss: 0.0550
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9761 - loss: 0.0396 - val_acc: 0.9615 - val_loss: 0.0549
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9782 - loss: 0.0394 - val_acc: 0.9615 - val_loss: 0.0555
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9782 - loss: 0.0391 - val_acc: 0.9615 - val_loss: 0.0551
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9775 - loss: 0.0386 - val_acc: 0.9615 - val_loss: 0.0546
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9754 - loss: 0.0386 - val_acc: 0.9615 - val_loss: 0.0544
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9761 - loss: 0.0382 - val_acc: 0.9615 - val_loss: 0.0543
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9775 - loss: 0.0378 - val_acc: 0.9615 - val_loss: 0.0547
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9789 - loss: 0.0377 - val_acc: 0.9615 - val_loss: 0.0549
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9782 - loss: 0.0373 - val_acc: 0.9615 - val_loss: 0.0544
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9768 - loss: 0.0371 - val_acc: 0.9615 - val_loss: 0.0537
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9768 - loss: 0.0369 - val_acc: 0.9615 - val_loss: 0.0538
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9782 - loss: 0.0366 - val_acc: 0.9615 - val_loss: 0.0538
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9789 - loss: 0.0363 - val_acc: 0.9615 - val_loss: 0.0540
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9796 - loss: 0.0360 - val_acc: 0.9615 - val_loss: 0.0535
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9789 - loss: 0.0358 - val_acc: 0.9615 - val_loss: 0.0532
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9768 - loss: 0.0355 - val_acc: 0.9615 - val_loss: 0.0530
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9796 - loss: 0.0353 - val_acc: 0.9615 - val_loss: 0.0532
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9796 - loss: 0.0352 - val_acc: 0.9615 - val_loss: 0.0533
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9789 - loss: 0.0349 - val_acc: 0.9615 - val_loss: 0.0530
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9804 - loss: 0.0346 - val_acc: 0.9615 - val_loss: 0.0531
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9804 - loss: 0.0342 - val_acc: 0.9615 - val_loss: 0.0528
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9804 - loss: 0.0340 - val_acc: 0.9615 - val_loss: 0.0525
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9782 - loss: 0.0338 - val_acc: 0.9615 - val_loss: 0.0522
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9796 - loss: 0.0337 - val_acc: 0.9615 - val_loss: 0.0523
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9796 - loss: 0.0333 - val_acc: 0.9615 - val_loss: 0.0523
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9789 - loss: 0.0332 - val_acc: 0.9615 - val_loss: 0.0521
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9796 - loss: 0.0329 - val_acc: 0.9615 - val_loss: 0.0519
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9796 - loss: 0.0325 - val_acc: 0.9615 - val_loss: 0.0520
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9818 - loss: 0.0323 - val_acc: 0.9615 - val_loss: 0.0518
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9825 - loss: 0.0320 - val_acc: 0.9615 - val_loss: 0.0516
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9804 - loss: 0.0318 - val_acc: 0.9615 - val_loss: 0.0513
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9804 - loss: 0.0315 - val_acc: 0.9615 - val_loss: 0.0514
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.
500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9860 - loss: 0.0243 - val_acc: 0.9583 - val_loss: 0.0477
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9853 - loss: 0.0241 - val_acc: 0.9583 - val_loss: 0.0479
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9860 - loss: 0.0239 - val_acc: 0.9583 - val_loss: 0.0478
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9860 - loss: 0.0237 - val_acc: 0.9583 - val_loss: 0.0479
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9853 - loss: 0.0236 - val_acc: 0.9615 - val_loss: 0.0479
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9860 - loss: 0.0234 - val_acc: 0.9615 - val_loss: 0.0473
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9874 - loss: 0.0232 - val_acc: 0.9583 - val_loss: 0.0474
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9874 - loss: 0.0230 - val_acc: 0.9583 - val_loss: 0.0475
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9867 - loss: 0.0229 - val_acc: 0.9583 - val_loss: 0.0478
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9860 - loss: 0.0228 - val_acc: 0.9583 - val_loss: 0.0473
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9874 - loss: 0.0224 - val_acc: 0.9583 - val_loss: 0.0470
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.9874 - loss: 0.0223 - val_acc: 0.9583 - val_loss: 0.0470
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9881 - loss: 0.0222 - val_acc: 0.9583 - val_loss: 0.0472
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9874 - loss: 0.0219 - val_acc: 0.9615 - val_loss: 0.0471
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9881 - loss: 0.0217 - val_acc: 0.9615 - val_loss: 0.0472
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9881 - loss: 0.0215 - val_acc: 0.9615 - val_loss: 0.0467
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9888 - loss: 0.0215 - val_acc: 0.9583 - val_loss: 0.0468
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9888 - loss: 0.0212 - val_acc: 0.9615 - val_loss: 0.0465
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9888 - loss: 0.0210 - val_acc: 0.9615 - val_loss: 0.0467
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9895 - loss: 0.0208 - val_acc: 0.9615 - val_loss: 0.0468
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9888 - loss: 0.0207 - val_acc: 0.9615 - val_loss: 0.0469
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9888 - loss: 0.0205 - val_acc: 0.9615 - val_loss: 0.0462
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9888 - loss: 0.0203 - val_acc: 0.9615 - val_loss: 0.0462
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9895 - loss: 0.0202 - val_acc: 0.9615 - val_loss: 0.0468
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.9895 - loss: 0.0200 - val_acc: 0.9615 - val_loss: 0.0467
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9895 - loss: 0.0199 - val_acc: 0.9615 - val_loss: 0.0464
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9895 - loss: 0.0197 - val_acc: 0.9615 - val_loss: 0.0462
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.9902 - loss: 0.0195 - val_acc: 0.9615 - val_loss: 0.0462
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9895 - loss: 0.0193 - val_acc: 0.9615 - val_loss: 0.0465
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.9895 - loss: 0.0192 - val_acc: 0.9615 - val_loss: 0.0464

# %%
debug(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])

plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['acc', 'loss', 'val_acc', 'val_loss'])

# %% [markdown]
# ## Test the model

# %%
(test_loss, test_accuracy) = model.evaluate(X_test_vec, Y_test_enc)

report(f"**test loss:** {test_loss}")
report(f"**test accuracy:** {test_accuracy}")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.9491 - loss: 0.0688
# **test loss:** 0.06880063563585281
# **test accuracy:** 0.9491018056869507
