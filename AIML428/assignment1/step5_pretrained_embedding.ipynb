# %% [markdown]
# # AIML428 - Assignment1, Step 5 Pre-Trained Word Embedding
# * Using Glove 50D, no need to load more data than necessary here.

# %%
import keras
import matplotlib.pyplot as plt
import numpy
import os
import pandas as pd
import torch
from IPython.display import Markdown, display
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from keras import layers
from keras.models import Sequential
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split

# %%
def tableHeader():
    doc = "|Algorithm| label | accuracy | precision | recall | f1 |\n"
    doc += "| --- | --- | --- | --- |--- | --- |\n"
    return doc

def tableScore(labels, doc, prefix=None, y_true=None, y_prediction=None):
    rows = ""
    accuracy = accuracy_score(y_true, y_prediction)
    precisions = precision_score(y_true, y_prediction, labels=labels, average=None)
    recalls = recall_score(y_true, y_prediction, labels=labels, average=None)
    f1s = f1_score(y_true, y_prediction, labels=labels, average=None)
    for label, precision, recall, f1 in zip(labels, precisions, recalls, f1s):
        rows += f"| {prefix} | {label} | {accuracy:.4g} | {precision:.4g} | {recall:.4g} | {f1:.4g} |\n"
        prefix = " "
    return doc + rows

def tableFooter(doc):
    display(Markdown(doc))

def report(string):
    display(Markdown(string))

enable_debug = True

def debug(string):
    if (enable_debug):
        print(string)

# %% [markdown]
# ## Try to use a GPU for go faster juice

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Metal (GPU) is available")
else:
    device = torch.device("cpu")
    print("GPU not available, using CPU")

# Encourage Keras to use Torch, and to use the GPU.
os.environ["KERAS_BACKEND"] = "torch"
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
# Out:
# Metal (GPU) is available

# %% [markdown]
# ## Magic to download wordnet

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/jepollock/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jepollock/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/jepollock/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Load the Glove Pre-Trained Embedding
#
# * File is space delimited, `<word> <num> <num> <num>
# * Online documentation is wrong it isn't whitespace delimited, it's _space_ delimited.

# %%
# Bugs: \n on end of line
# Convert embedding from string to float.

def loadGloveEmbedding(filename=None):
    word_to_embedding = {}
    with open(filename, "r") as file:
        for line in file:
            # Can't use the default, because words include nbsp.
            fields = line.rstrip().split(" ")
            word = fields[0]
            try:
                embedding = [float(x) for x in fields[1:]]
            except ValueError:
                print(f"value error: {fields}")
                raise ValueError("BOOM.")
            word_to_embedding[word] = embedding
    return word_to_embedding

embedding = loadGloveEmbedding("data/wiki_giga_2024_50_MFT20_vectors_seed_123_alpha_0.75_eta_0.075_combined.txt")

first_embedding, *_ = embedding.items()
embedding_num_dims=len(first_embedding[1])

debug(f"config_dims= {embedding_num_dims}")
debug(f"first embedding: {first_embedding}")
# Out:
# config_dims= 50
# first embedding: ('the', [-0.383396, -0.480674, -0.27414099999999997, 0.132697, 0.06488499999999997, -0.092489, -0.0029909999999999937, 0.168918, 0.42769, 0.032062000000000035, 0.600652, 0.0045550000000000035, 0.221568, -0.106817, 0.339955, -0.24816500000000002, -0.06553399999999998, 0.16503099999999998, -0.098915, -0.26706, -0.351612, -0.595836, -0.748328, -0.262191, -0.400183, 0.306477, 0.13247, 0.149532, -0.462982, 0.436406, -0.328406, -0.11229700000000001, -0.318158, -0.586177, -0.24174600000000002, -0.38285899999999995, -0.433786, 5.955204999999999, 0.137239, -0.064516, 0.456522, -0.019239000000000006, 0.260624, -0.293577, 0.19897499999999999, 0.277653, 0.164552, 0.40649, -0.227907, -0.400316])

# %% [markdown]
# ## Load the data.

# %%
df_csv = pd.read_csv('bbc_converted.csv')

feature_columns = ['text']
target_column = 'category'

X_csv = df_csv[feature_columns]
Y_csv = df_csv[target_column]
# unique converts to an NDArray, so the sort needs to happen first.
labels = Y_csv.sort_values().unique()
print(labels)
# Out:
# ['business' 'entertainment' 'politics' 'sport' 'tech']

# %%
# https://xkcd.com/221/ - 4 is overused
random_seed = 221

# %%
# Data already loaded
# X_csv is the CSV text data
# Y_csv is the CSV labels - the sorted label set.
debug(X_csv)
debug(Y_csv)
debug(labels)
# Out:
#                                                    text
# 0     musicians to tackle us red tape musicians grou...
# 1     u2 s desire to be number one u2 who have won t...
# 2     rocker doherty in on stage fight rock singer p...
# 3     snicket tops us box office chart the film adap...
# 4     ocean s twelve raids box office ocean s twelve...
# ...                                                 ...
# 2220  warning over windows word files writing a micr...
# 2221  fast lifts rise into record books two high spe...
# 2222  nintendo adds media playing to ds nintendo is ...
# 2223  fast moving phone viruses appear security firm...
# 2224  hacker threat to apple s itunes users of apple...
#
# [2225 rows x 1 columns]
# 0       entertainment
# 1       entertainment
# 2       entertainment
# 3       entertainment
# 4       entertainment
#             ...
# 2220             tech
# 2221             tech
# 2222             tech
# 2223             tech
# 2224             tech
# Name: category, Length: 2225, dtype: object
# ['business' 'entertainment' 'politics' 'sport' 'tech']

# %% [markdown]
# ## Data preprocessing - lemmatization
# * Lemmatization is a preprocessing step, it is applied to the dataset, not learned from Training and applied to Test.

# %%
# From Part-of-speech tagging guidelines for the Penn Treebank Project.
# https://catalog.ldc.upenn.edu/docs/LDC99T42/tagguid1.pdf
tag_dict = {"J": "a", "R":"r", "V": "v"}

def treebank_to_wordnet(treebank_tag:str):
  # n - nouns
  # a - adjective
  # r - adverb
  # s - satellite adjectives
  # default is h
  if (treebank_tag.startswith("WRB")):
      return "r"
  return tag_dict.get(treebank_tag[0], "n")

lemmatizer = WordNetLemmatizer()

def lemmatizeText(text:str):
    accum = []
    tagged_values = pos_tag(word_tokenize(text))
    for t, pos in tagged_values:
        wordnet_tag = treebank_to_wordnet(pos)
        #debug(f"from ({t},{pos}, {wordnet_tag})")
        lemmatized = lemmatizer.lemmatize(word=t,pos=wordnet_tag)
        accum.append(lemmatized)
    result = ' '.join(accum)
    #debug(result)
    return result

X_lemmatized = pd.DataFrame()
X_lemmatized['text'] = X_csv.text.apply(lemmatizeText)

X_lemmatized
# Out:
#                                                    text
# 0     musician to tackle u red tape musician group b...
# 1     u2 s desire to be number one u2 who have win t...
# 2     rocker doherty in on stage fight rock singer p...
# 3     snicket top u box office chart the film adapta...
# 4     ocean s twelve raid box office ocean s twelve ...
# ...                                                 ...
# 2220  warn over window word file write a microsoft w...
# 2221  fast lifts rise into record book two high spee...
# 2222  nintendo add medium play to ds nintendo be rel...
# 2223  fast move phone virus appear security firm be ...
# 2224  hacker threat to apple s itunes user of apple ...
#
# [2225 rows x 1 columns]

# %% [markdown]
# ## Test/Train Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_lemmatized, Y_csv, test_size= 0.3, random_state=random_seed)

debug(f"X columns: {X_train.columns}")
debug(f"X.head: {X_train.text.head(1)}")
debug(f"Y.head: {Y_train.head(1)}")
# Out:
# X columns: Index(['text'], dtype='object')
# X.head: 1187    edward tip idowu for euro gold world outdoor t...
# Name: text, dtype: object
# Y.head: 1187    sport
# Name: category, dtype: object

# %% [markdown]
# ## Create Validation Set
#
# We do it here to make it easier. Tensors can't use the same functions, and the ones they have are interesting in other ways.

# %%
X_train_wv, X_validation, Y_train_wv, Y_validation = (
   train_test_split(X_train, Y_train, test_size=0.2, random_state=random_seed))

# %% [markdown]
# ## Use oversampling for balance - only the training set
#
# SMOTE and ADASYN only work on numeric data. Could do it by converting to vector space too, but that is too much for for today.

# %%
random_oversampler = RandomOverSampler(random_state=random_seed)
X_train_rs, Y_train_rs = random_oversampler.fit_resample(X_train_wv, Y_train_wv)

debug(sorted(Counter(Y_train_rs.tolist()).items()))
debug(X_train_rs.shape)
debug(Y_train_rs.shape)
# Out:
# [('business', 285), ('entertainment', 285), ('politics', 285), ('sport', 285), ('tech', 285)]
# (1425, 1)
# (1425,)

# %% [markdown]
# ## Encode the label
#
# Train on all the _training_ values, but apply it to the _train/_validation variables, and the _test variables.

# %%
# label encode the target variable
encoder = preprocessing.OneHotEncoder(sparse_output=False)

encoder.fit(Y_train.values.reshape(-1, 1))
Y_train_enc = encoder.transform(Y_train_rs.values.reshape(-1, 1))
Y_validation_enc = encoder.transform(Y_validation.values.reshape(-1, 1))
Y_test_enc = encoder.transform(Y_test.values.reshape(-1, 1))

debug(f"Y_train_enc.shape: {Y_train_enc.shape}")
# Out:
# Y_train_enc.shape: (1425, 5)

# %% [markdown]
# ## Vectorization to have an index.
# * train on the entire dataset
# * then vectorize test, train and validation independently

# %%
from tensorflow.keras.layers import TextVectorization

# This is the bit we are going to change with fasttext.

max_tokens = 50000  # Maximum vocab size.
max_len = 70  # Sequence length to pad the outputs to.

vectorize_layer = TextVectorization(
    max_tokens=max_tokens,
    output_mode='int',
    output_sequence_length=max_len)

# Adapt the layer to the training text.
# Create a dict and go.
vectorize_layer.adapt(X_train)
train_vocabulary = vectorize_layer.get_vocabulary()
train_vocab_len = len(train_vocabulary)
X_train_vec = vectorize_layer(X_train_rs)
X_test_vec = vectorize_layer(X_test)
X_validation_vec = vectorize_layer(X_validation)

X_train_vec
# Out:
# <tf.Tensor: shape=(1425, 70), dtype=int64, numpy=
# array([[ 1677, 15823,    12, ...,    79,  8147,    12],
#        [ 2517,   404,     4, ..., 21125,   404,    13],
#        [  518,  2631,     5, ...,     2,   453,   391],
#        ...,
#        [  518,  2631,     5, ...,     2,   453,   391],
#        [  461,   506,     4, ...,   286,    24,   126],
#        [  379,  1493,  2399, ...,    21,    62,     2]])>

# %% [markdown]
# ## Convert loaded Pre-Trained embedding weights into a matrix
#
# * Uses the trained vectorization
# * Inserts them in-order

# %%
# Vocabulary is already in order, there is no need to map it to a dict.
no_mapping = [0] * embedding_num_dims

def translateWord(value):
    vector = embedding.get(value, no_mapping)
    return numpy.array(vector)

embedding_matrix = numpy.array(list(map(translateWord, train_vocabulary)))

debug(len(train_vocabulary))
debug(train_vocab_len)
debug(len(embedding_matrix))
debug(embedding_matrix.shape)

# The code in here is broken: https://realpython.com/python-keras-text-classification/#using-pretrained-word-embeddings
# The code in here is _also_ broken https://keras.io/examples/nlp/pretrained_word_embeddings/
# BUG: word, coefs = line.split(maxsplit=1) -- breaks on nbsp's in words e.g. "..."
# BUG: word_index = dict(zip(voc, range(len(voc)))) -- dict isn't required if the words are in order already.
# Out:
# 21268
# 21268
# 21268
# (21268, 50)

# %% [markdown]
# ## Train the CNN using
# * Data is Lemmatized
# * Data has a validation set
# * Training data was oversampled.
# * Uses Early Stopping

# %%
vocab_size = train_vocab_len
print("vocab_size:", vocab_size)
maxDocumentLength = 70
earlyStoppingMinDelta = 0.0001
earlyStoppingPatience = 8
epochs=500 # demonstrate early stopping works.

model = Sequential()

embedding_layer_name = "Embedding"
model.add(layers.Embedding(
    weights=[embedding_matrix],
    name=embedding_layer_name,
    input_dim=vocab_size,
    output_dim=50, trainable=False))
model.build((50, maxDocumentLength)) # build the first layer with the specific input_length
model.add(layers.Conv1D(filters=128, kernel_size=5, activation='relu'))

model.add(layers.GlobalAveragePooling1D())
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(Y_train_enc.shape[1], activation='sigmoid'))

model.summary()

early_stopping_callback = keras.callbacks.EarlyStopping(monitor="val_loss",
                                                        min_delta=earlyStoppingMinDelta,
                                                        restore_best_weights=True,
                                                        patience=earlyStoppingPatience)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc',])

print(X_train_vec.shape)
print(Y_train_enc.shape)
print(X_validation_vec.shape)
print(Y_validation_enc.shape)

history = model.fit(X_train_vec,
                    Y_train_enc,
                    callbacks=[early_stopping_callback],
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(X_validation_vec, Y_validation_enc),
                    verbose=1)
# Out:
# vocab_size: 21268
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Embedding (Embedding)           │ (50, 70, 50)           │     1,063,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (50, 66, 128)          │        32,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (50, 128)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (50, 16)               │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (50, 5)                │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,097,677 (4.19 MB)
#  Trainable params: 34,277 (133.89 KB)
#  Non-trainable params: 1,063,400 (4.06 MB)
# (1425, 70)
# (1425, 5)
# (312, 70)
# (312, 5)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - acc: 0.2000 - loss: 0.6493 - val_acc: 0.2628 - val_loss: 0.6042
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.2947 - loss: 0.5871 - val_acc: 0.1987 - val_loss: 0.5502
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.2070 - loss: 0.5382 - val_acc: 0.2019 - val_loss: 0.5086
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.2056 - loss: 0.4984 - val_acc: 0.2115 - val_loss: 0.4723
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.2337 - loss: 0.4611 - val_acc: 0.2788 - val_loss: 0.4380
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.3558 - loss: 0.4245 - val_acc: 0.5128 - val_loss: 0.4058
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.5825 - loss: 0.3908 - val_acc: 0.6667 - val_loss: 0.3767
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.7354 - loss: 0.3609 - val_acc: 0.7436 - val_loss: 0.3502
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.7782 - loss: 0.3351 - val_acc: 0.7821 - val_loss: 0.3258
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.8035 - loss: 0.3114 - val_acc: 0.7949 - val_loss: 0.3035
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.8386 - loss: 0.2904 - val_acc: 0.8365 - val_loss: 0.2828
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.8618 - loss: 0.2707 - val_acc: 0.8526 - val_loss: 0.2632
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.8821 - loss: 0.2518 - val_acc: 0.8526 - val_loss: 0.2447
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.8877 - loss: 0.2343 - val_acc: 0.8622 - val_loss: 0.2283
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.8919 - loss: 0.2183 - val_acc: 0.8718 - val_loss: 0.2139
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.8975 - loss: 0.2041 - val_acc: 0.8750 - val_loss: 0.2001
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9018 - loss: 0.1911 - val_acc: 0.8814 - val_loss: 0.1873
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9053 - loss: 0.1793 - val_acc: 0.8846 - val_loss: 0.1761
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.9088 - loss: 0.1685 - val_acc: 0.8942 - val_loss: 0.1664
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9109 - loss: 0.1587 - val_acc: 0.8942 - val_loss: 0.1575
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9172 - loss: 0.1501 - val_acc: 0.8974 - val_loss: 0.1484
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9200 - loss: 0.1420 - val_acc: 0.9199 - val_loss: 0.1410
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9200 - loss: 0.1350 - val_acc: 0.9167 - val_loss: 0.1338
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9228 - loss: 0.1287 - val_acc: 0.9231 - val_loss: 0.1280
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9263 - loss: 0.1235 - val_acc: 0.9231 - val_loss: 0.1231
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9305 - loss: 0.1182 - val_acc: 0.9295 - val_loss: 0.1169
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9298 - loss: 0.1139 - val_acc: 0.9295 - val_loss: 0.1126
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9312 - loss: 0.1099 - val_acc: 0.9295 - val_loss: 0.1092
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9326 - loss: 0.1063 - val_acc: 0.9359 - val_loss: 0.1055
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9319 - loss: 0.1030 - val_acc: 0.9359 - val_loss: 0.1024
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9312 - loss: 0.1003 - val_acc: 0.9359 - val_loss: 0.0995
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9333 - loss: 0.0974 - val_acc: 0.9423 - val_loss: 0.0963
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9347 - loss: 0.0951 - val_acc: 0.9423 - val_loss: 0.0941
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9361 - loss: 0.0930 - val_acc: 0.9423 - val_loss: 0.0927
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9368 - loss: 0.0908 - val_acc: 0.9423 - val_loss: 0.0906
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.9361 - loss: 0.0888 - val_acc: 0.9423 - val_loss: 0.0880
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9368 - loss: 0.0871 - val_acc: 0.9455 - val_loss: 0.0864
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9368 - loss: 0.0855 - val_acc: 0.9487 - val_loss: 0.0851
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9418 - loss: 0.0838 - val_acc: 0.9455 - val_loss: 0.0843
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9418 - loss: 0.0826 - val_acc: 0.9455 - val_loss: 0.0822
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9453 - loss: 0.0810 - val_acc: 0.9487 - val_loss: 0.0812
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9481 - loss: 0.0798 - val_acc: 0.9519 - val_loss: 0.0801
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9488 - loss: 0.0785 - val_acc: 0.9519 - val_loss: 0.0786
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9488 - loss: 0.0775 - val_acc: 0.9519 - val_loss: 0.0777
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9502 - loss: 0.0762 - val_acc: 0.9519 - val_loss: 0.0767
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9523 - loss: 0.0753 - val_acc: 0.9519 - val_loss: 0.0758
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9509 - loss: 0.0743 - val_acc: 0.9519 - val_loss: 0.0751
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9509 - loss: 0.0734 - val_acc: 0.9519 - val_loss: 0.0745
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9530 - loss: 0.0724 - val_acc: 0.9519 - val_loss: 0.0734
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9544 - loss: 0.0716 - val_acc: 0.9519 - val_loss: 0.0732
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9530 - loss: 0.0707 - val_acc: 0.9551 - val_loss: 0.0723
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9516 - loss: 0.0699 - val_acc: 0.9519 - val_loss: 0.0717
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9537 - loss: 0.0690 - val_acc: 0.9519 - val_loss: 0.0711
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9537 - loss: 0.0684 - val_acc: 0.9551 - val_loss: 0.0707
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9544 - loss: 0.0677 - val_acc: 0.9551 - val_loss: 0.0697
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9544 - loss: 0.0673 - val_acc: 0.9519 - val_loss: 0.0693
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9537 - loss: 0.0662 - val_acc: 0.9583 - val_loss: 0.0696
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9572 - loss: 0.0660 - val_acc: 0.9551 - val_loss: 0.0699
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9572 - loss: 0.0651 - val_acc: 0.9551 - val_loss: 0.0676
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9544 - loss: 0.0645 - val_acc: 0.9551 - val_loss: 0.0670
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9537 - loss: 0.0637 - val_acc: 0.9551 - val_loss: 0.0677
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.9579 - loss: 0.0633 - val_acc: 0.9551 - val_loss: 0.0679
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9572 - loss: 0.0627 - val_acc: 0.9583 - val_loss: 0.0662
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9565 - loss: 0.0622 - val_acc: 0.9551 - val_loss: 0.0655
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9600 - loss: 0.0615 - val_acc: 0.9551 - val_loss: 0.0660
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9593 - loss: 0.0610 - val_acc: 0.9551 - val_loss: 0.0659
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9607 - loss: 0.0604 - val_acc: 0.9583 - val_loss: 0.0648
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9607 - loss: 0.0599 - val_acc: 0.9583 - val_loss: 0.0642
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9614 - loss: 0.0595 - val_acc: 0.9615 - val_loss: 0.0643
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9628 - loss: 0.0590 - val_acc: 0.9583 - val_loss: 0.0644
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9621 - loss: 0.0584 - val_acc: 0.9583 - val_loss: 0.0642
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.9621 - loss: 0.0581 - val_acc: 0.9551 - val_loss: 0.0633
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9621 - loss: 0.0577 - val_acc: 0.9583 - val_loss: 0.0630
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9614 - loss: 0.0573 - val_acc: 0.9551 - val_loss: 0.0633
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9635 - loss: 0.0568 - val_acc: 0.9583 - val_loss: 0.0634
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9635 - loss: 0.0564 - val_acc: 0.9583 - val_loss: 0.0623
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.9656 - loss: 0.0559 - val_acc: 0.9583 - val_loss: 0.0624
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9649 - loss: 0.0556 - val_acc: 0.9615 - val_loss: 0.0617
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9642 - loss: 0.0551 - val_acc: 0.9615 - val_loss: 0.0612
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.9649 - loss: 0.0546 - val_acc: 0.9583 - val_loss: 0.0617
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9656 - loss: 0.0542 - val_acc: 0.9583 - val_loss: 0.0613
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 0.9656 - loss: 0.0537 - val_acc: 0.9583 - val_loss: 0.0607
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9656 - loss: 0.0534 - val_acc: 0.9583 - val_loss: 0.0602
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9649 - loss: 0.0530 - val_acc: 0.9583 - val_loss: 0.0604
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9663 - loss: 0.0527 - val_acc: 0.9583 - val_loss: 0.0603
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9663 - loss: 0.0521 - val_acc: 0.9583 - val_loss: 0.0598
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9649 - loss: 0.0519 - val_acc: 0.9583 - val_loss: 0.0595
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.9663 - loss: 0.0514 - val_acc: 0.9583 - val_loss: 0.0598
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9663 - loss: 0.0512 - val_acc: 0.9583 - val_loss: 0.0601
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9663 - loss: 0.0509 - val_acc: 0.9583 - val_loss: 0.0588
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9663 - loss: 0.0504 - val_acc: 0.9583 - val_loss: 0.0585
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9656 - loss: 0.0501 - val_acc: 0.9583 - val_loss: 0.0589
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9663 - loss: 0.0496 - val_acc: 0.9583 - val_loss: 0.0594
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9670 - loss: 0.0495 - val_acc: 0.9583 - val_loss: 0.0585
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9670 - loss: 0.0489 - val_acc: 0.9583 - val_loss: 0.0578
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9670 - loss: 0.0487 - val_acc: 0.9583 - val_loss: 0.0578
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9670 - loss: 0.0483 - val_acc: 0.9583 - val_loss: 0.0581
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9691 - loss: 0.0481 - val_acc: 0.9583 - val_loss: 0.0584
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9691 - loss: 0.0478 - val_acc: 0.9583 - val_loss: 0.0573
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9677 - loss: 0.0474 - val_acc: 0.9583 - val_loss: 0.0572
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9677 - loss: 0.0474 - val_acc: 0.9583 - val_loss: 0.0580
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9691 - loss: 0.0470 - val_acc: 0.9583 - val_loss: 0.0571
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9684 - loss: 0.0467 - val_acc: 0.9583 - val_loss: 0.0565
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9705 - loss: 0.0465 - val_acc: 0.9583 - val_loss: 0.0572
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9698 - loss: 0.0461 - val_acc: 0.9583 - val_loss: 0.0567
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9691 - loss: 0.0456 - val_acc: 0.9583 - val_loss: 0.0567
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.9705 - loss: 0.0457 - val_acc: 0.9583 - val_loss: 0.0563
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.9705 - loss: 0.0450 - val_acc: 0.9583 - val_loss: 0.0565
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9726 - loss: 0.0447 - val_acc: 0.9583 - val_loss: 0.0565
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9712 - loss: 0.0445 - val_acc: 0.9583 - val_loss: 0.0557
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9705 - loss: 0.0442 - val_acc: 0.9583 - val_loss: 0.0556
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9712 - loss: 0.0440 - val_acc: 0.9583 - val_loss: 0.0562
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9726 - loss: 0.0440 - val_acc: 0.9583 - val_loss: 0.0564
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9740 - loss: 0.0434 - val_acc: 0.9583 - val_loss: 0.0555
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9726 - loss: 0.0431 - val_acc: 0.9615 - val_loss: 0.0553
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.9719 - loss: 0.0429 - val_acc: 0.9583 - val_loss: 0.0553
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9740 - loss: 0.0426 - val_acc: 0.9551 - val_loss: 0.0556
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - acc: 0.9740 - loss: 0.0424 - val_acc: 0.9583 - val_loss: 0.0555
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 0.9747 - loss: 0.0421 - val_acc: 0.9551 - val_loss: 0.0548
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9740 - loss: 0.0419 - val_acc: 0.9583 - val_loss: 0.0545
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9740 - loss: 0.0416 - val_acc: 0.9583 - val_loss: 0.0544
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9740 - loss: 0.0414 - val_acc: 0.9551 - val_loss: 0.0547
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9740 - loss: 0.0411 - val_acc: 0.9551 - val_loss: 0.0550
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9747 - loss: 0.0409 - val_acc: 0.9551 - val_loss: 0.0545
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.9754 - loss: 0.0406 - val_acc: 0.9551 - val_loss: 0.0542
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9740 - loss: 0.0405 - val_acc: 0.9551 - val_loss: 0.0547
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9740 - loss: 0.0401 - val_acc: 0.9551 - val_loss: 0.0541
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9740 - loss: 0.0401 - val_acc: 0.9551 - val_loss: 0.0541
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9747 - loss: 0.0397 - val_acc: 0.9551 - val_loss: 0.0542
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9761 - loss: 0.0398 - val_acc: 0.9551 - val_loss: 0.0546
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9740 - loss: 0.0392 - val_acc: 0.9583 - val_loss: 0.0536
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9740 - loss: 0.0391 - val_acc: 0.9583 - val_loss: 0.0535
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9740 - loss: 0.0388 - val_acc: 0.9551 - val_loss: 0.0537
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.9747 - loss: 0.0387 - val_acc: 0.9551 - val_loss: 0.0544
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9747 - loss: 0.0386 - val_acc: 0.9551 - val_loss: 0.0535
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9747 - loss: 0.0382 - val_acc: 0.9583 - val_loss: 0.0533
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9740 - loss: 0.0380 - val_acc: 0.9551 - val_loss: 0.0535
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9740 - loss: 0.0376 - val_acc: 0.9551 - val_loss: 0.0535
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9761 - loss: 0.0378 - val_acc: 0.9551 - val_loss: 0.0535
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9754 - loss: 0.0373 - val_acc: 0.9551 - val_loss: 0.0526
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9740 - loss: 0.0373 - val_acc: 0.9583 - val_loss: 0.0526
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9754 - loss: 0.0370 - val_acc: 0.9551 - val_loss: 0.0531
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9775 - loss: 0.0367 - val_acc: 0.9551 - val_loss: 0.0533
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9775 - loss: 0.0364 - val_acc: 0.9551 - val_loss: 0.0526
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9754 - loss: 0.0363 - val_acc: 0.9551 - val_loss: 0.0522
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9761 - loss: 0.0361 - val_acc: 0.9551 - val_loss: 0.0527
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9775 - loss: 0.0359 - val_acc: 0.9551 - val_loss: 0.0531
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9768 - loss: 0.0357 - val_acc: 0.9487 - val_loss: 0.0524
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9747 - loss: 0.0356 - val_acc: 0.9551 - val_loss: 0.0520
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9754 - loss: 0.0352 - val_acc: 0.9551 - val_loss: 0.0523
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9789 - loss: 0.0350 - val_acc: 0.9551 - val_loss: 0.0529
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9796 - loss: 0.0348 - val_acc: 0.9519 - val_loss: 0.0524
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9782 - loss: 0.0346 - val_acc: 0.9455 - val_loss: 0.0523
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9747 - loss: 0.0345 - val_acc: 0.9519 - val_loss: 0.0518
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9782 - loss: 0.0344 - val_acc: 0.9551 - val_loss: 0.0520
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9796 - loss: 0.0340 - val_acc: 0.9519 - val_loss: 0.0517
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9789 - loss: 0.0339 - val_acc: 0.9455 - val_loss: 0.0517
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9796 - loss: 0.0337 - val_acc: 0.9551 - val_loss: 0.0523
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9811 - loss: 0.0335 - val_acc: 0.9551 - val_loss: 0.0515
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9789 - loss: 0.0333 - val_acc: 0.9519 - val_loss: 0.0512
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9789 - loss: 0.0330 - val_acc: 0.9455 - val_loss: 0.0514
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9804 - loss: 0.0328 - val_acc: 0.9455 - val_loss: 0.0515
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9804 - loss: 0.0326 - val_acc: 0.9519 - val_loss: 0.0513
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9804 - loss: 0.0325 - val_acc: 0.9519 - val_loss: 0.0509
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9811 - loss: 0.0322 - val_acc: 0.9455 - val_loss: 0.0509
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9811 - loss: 0.0321 - val_acc: 0.9455 - val_loss: 0.0507
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9796 - loss: 0.0319 - val_acc: 0.9519 - val_loss: 0.0509
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9811 - loss: 0.0318 - val_acc: 0.9455 - val_loss: 0.0512
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9811 - loss: 0.0315 - val_acc: 0.9455 - val_loss: 0.0507
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9818 - loss: 0.0314 - val_acc: 0.9455 - val_loss: 0.0507
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.9825 - loss: 0.0312 - val_acc: 0.9455 - val_loss: 0.0505
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9825 - loss: 0.0310 - val_acc: 0.9519 - val_loss: 0.0504
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9825 - loss: 0.0309 - val_acc: 0.9455 - val_loss: 0.0504
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9825 - loss: 0.0306 - val_acc: 0.9455 - val_loss: 0.0504
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9818 - loss: 0.0306 - val_acc: 0.9423 - val_loss: 0.0510
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9818 - loss: 0.0302 - val_acc: 0.9455 - val_loss: 0.0511
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9818 - loss: 0.0301 - val_acc: 0.9519 - val_loss: 0.0506
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9825 - loss: 0.0300 - val_acc: 0.9455 - val_loss: 0.0501
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9818 - loss: 0.0298 - val_acc: 0.9455 - val_loss: 0.0503
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.9818 - loss: 0.0296 - val_acc: 0.9455 - val_loss: 0.0506
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9825 - loss: 0.0294 - val_acc: 0.9455 - val_loss: 0.0502
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9818 - loss: 0.0293 - val_acc: 0.9519 - val_loss: 0.0498
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9825 - loss: 0.0291 - val_acc: 0.9519 - val_loss: 0.0501
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9832 - loss: 0.0290 - val_acc: 0.9423 - val_loss: 0.0505
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9832 - loss: 0.0288 - val_acc: 0.9423 - val_loss: 0.0506
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9825 - loss: 0.0286 - val_acc: 0.9455 - val_loss: 0.0496
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9825 - loss: 0.0285 - val_acc: 0.9519 - val_loss: 0.0498
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9825 - loss: 0.0283 - val_acc: 0.9455 - val_loss: 0.0495
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.9839 - loss: 0.0282 - val_acc: 0.9455 - val_loss: 0.0499
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.9846 - loss: 0.0278 - val_acc: 0.9455 - val_loss: 0.0501
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.9832 - loss: 0.0278 - val_acc: 0.9455 - val_loss: 0.0498
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.9832 - loss: 0.0275 - val_acc: 0.9455 - val_loss: 0.0491
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.9846 - loss: 0.0273 - val_acc: 0.9455 - val_loss: 0.0490
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.9853 - loss: 0.0272 - val_acc: 0.9455 - val_loss: 0.0491
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.9839 - loss: 0.0269 - val_acc: 0.9455 - val_loss: 0.0494
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9839 - loss: 0.0268 - val_acc: 0.9455 - val_loss: 0.0495
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9839 - loss: 0.0264 - val_acc: 0.9455 - val_loss: 0.0488
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.9846 - loss: 0.0264 - val_acc: 0.9487 - val_loss: 0.0483
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9853 - loss: 0.0261 - val_acc: 0.9455 - val_loss: 0.0487
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9839 - loss: 0.0259 - val_acc: 0.9455 - val_loss: 0.0490
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9839 - loss: 0.0257 - val_acc: 0.9455 - val_loss: 0.0487
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9853 - loss: 0.0255 - val_acc: 0.9487 - val_loss: 0.0485
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9846 - loss: 0.0254 - val_acc: 0.9455 - val_loss: 0.0485
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9846 - loss: 0.0251 - val_acc: 0.9455 - val_loss: 0.0484
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9853 - loss: 0.0250 - val_acc: 0.9487 - val_loss: 0.0483
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9853 - loss: 0.0247 - val_acc: 0.9455 - val_loss: 0.0485

# %%
debug(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])

plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['acc', 'loss', 'val_acc', 'val_loss'])

# %% [markdown]
# ## Test the model

# %%
(test_loss, test_accuracy) = model.evaluate(X_test_vec, Y_test_enc)

report(f"**test loss:** {test_loss}")
report(f"**test accuracy:** {test_accuracy}")

Y_prediction = model.predict(X_test_vec)
# Translate labels out of 1-hot.
Y_prediction_categories = numpy.argmax(Y_prediction, axis=1)
Y_test_categories = numpy.argmax(Y_test_enc, axis=1)

from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(Y_test_categories, Y_prediction_categories, normalize='true')
conf_matrix_df = pd.DataFrame(conf_matrix, index=labels, columns=labels)

conf_matrix_df
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9401 - loss: 0.0731
# **test loss:** 0.07305749505758286
# **test accuracy:** 0.940119743347168
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#                business  entertainment  politics     sport      tech
# business       0.943038       0.000000  0.031646  0.000000  0.025316
# entertainment  0.017699       0.955752  0.000000  0.000000  0.026549
# politics       0.083333       0.000000  0.891667  0.008333  0.016667
# sport          0.006536       0.006536  0.006536  0.980392  0.000000
# tech           0.040323       0.016129  0.024194  0.000000  0.919355
